# %% [markdown]
# # Copyright 2022 Cognite AS
#
# ## Import the Libraries and Modules

# %%
import sys
from pathlib import Path

utils = str(Path("../../utils").resolve())
if utils not in sys.path:
    sys.path.append(utils)

from cognite_auth import interactive_client

# %% [markdown]
# ## Create the Cognite Client

# %%
c = interactive_client()
# Out:
# C:\Users\JoeO'Bryant\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\ipkernel.py:772: UserWarning: You are using version='7.85.0' of the SDK, however version='7.86.0' is available. To suppress this warning, either upgrade or do the following:
# >>> from cognite.client.config import global_config
# >>> global_config.disable_pypi_version_check = True
#   _threading_Thread_run(self)

# %% [markdown]
# ## List operation
#
# **Code Pattern**
# `client.<cdf_resource_type>.list()`
# where **cdf_resource_type** = { data_sets, assets, time_series, events, files, labels, sequences, relationships ... }

# %% [markdown]
# ### List the CDF Resource types

# %%
c.data_sets.list()
# Out:
# DataSetList([<cognite.client.data_classes.data_sets.DataSet at 0x18fba058d70>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe9208a50>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe91f0770>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe91f08a0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe920d010>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe918dae0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe918d8c0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe91e8f50>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe91e9650>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe915a3f0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe915a6c0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fb9fff230>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fea238050>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fba06c600>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe919d6d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe919d490>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe917a360>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe917a4c0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe91fbcf0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe91fbd90>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe91fbe30>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe91fbed0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fe91fbf70>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fea23c050>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18fea23c0f0>])

# %%
c.assets.list(limit=5)
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x18feb19a7b0>,
#            <cognite.client.data_classes.assets.Asset at 0x18fe9137250>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2363f0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2369e0>,
#            <cognite.client.data_classes.assets.Asset at 0x18fe91431d0>])

# %%
df = c.time_series.list(limit=None).to_pandas()

# %%
df.shape
# Out:
# (7234, 13)

# %%
c.events.list(limit=5)
# Out:
# EventList([<cognite.client.data_classes.events.Event at 0x18feb19a510>,
#            <cognite.client.data_classes.events.Event at 0x18feb259450>,
#            <cognite.client.data_classes.events.Event at 0x18feb236520>,
#            <cognite.client.data_classes.events.Event at 0x18feb235e00>,
#            <cognite.client.data_classes.events.Event at 0x18feb247410>])

# %%
c.files.list(limit=5)
# Out:
# FileMetadataList([<cognite.client.data_classes.files.FileMetadata at 0x18feb19a120>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb258f50>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb2368b0>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb236650>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb2472f0>])

# %% [markdown]
# Similar code for listing other resource types
#
#
# ```
# c.labels.list()
# ```
# ```
# c.sequences.list()
# ```
# ```
# c.relationships.list()
# ```

# %%
c.labels.list(limit=5)
# Out:
# LabelDefinitionList([<cognite.client.data_classes.labels.LabelDefinition at 0x18feb19b230>,
#                      <cognite.client.data_classes.labels.LabelDefinition at 0x18feb259590>,
#                      <cognite.client.data_classes.labels.LabelDefinition at 0x18feb236b10>,
#                      <cognite.client.data_classes.labels.LabelDefinition at 0x18feb236ea0>,
#                      <cognite.client.data_classes.labels.LabelDefinition at 0x18feb2471d0>])

# %%
c.sequences.list(limit=5)
# Out:
# SequenceList([<cognite.client.data_classes.sequences.Sequence at 0x18feb199fd0>,
#               <cognite.client.data_classes.sequences.Sequence at 0x18feb259950>,
#               <cognite.client.data_classes.sequences.Sequence at 0x18feb237100>,
#               <cognite.client.data_classes.sequences.Sequence at 0x18feb236fd0>,
#               <cognite.client.data_classes.sequences.Sequence at 0x18feb247bf0>])

# %%
c.relationships.list(limit=5)
# Out:
# RelationshipList([<cognite.client.data_classes.relationships.Relationship at 0x18feb19a3c0>,
#                   <cognite.client.data_classes.relationships.Relationship at 0x18feb259e50>,
#                   <cognite.client.data_classes.relationships.Relationship at 0x18feb237490>,
#                   <cognite.client.data_classes.relationships.Relationship at 0x18feb2375c0>,
#                   <cognite.client.data_classes.relationships.Relationship at 0x18feb247770>])

# %% [markdown]
# ### Filter the list results

# %% [markdown]
# using label filter, the data in cdf doesn't have these labels. But it is an example on how to filter with labels

# %%
from cognite.client.data_classes import LabelFilter

# %%
c.assets.list(labels=LabelFilter(contains_all=["industrial-assets"]),limit=5)
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x18feb2a1370>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2a1260>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb272750>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb272250>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb26a5d0>])

# %%
c.assets.list(labels=LabelFilter(contains_any=["industrial-assets"]))
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x18feb269e50>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c7bd0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c75b0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c7690>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c7930>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c6f90>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c7310>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c73f0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c74d0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c6dd0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c6cf0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c6c10>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c6b30>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c6a50>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c6890>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c67b0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c66d0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c6510>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c6430>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c6350>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c6190>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c60b0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c5e10>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c5d30>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c5c50>])

# %% [markdown]
# Other filters

# %%
c.data_sets.list()
# Out:
# DataSetList([<cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc0f0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc190>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc230>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc2d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc370>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc410>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc4b0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc550>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc5f0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc690>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc730>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc7d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc870>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc910>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bc9b0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bca50>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bcaf0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bcb90>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bcc30>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bccd0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bcd70>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bce10>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bceb0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bcf50>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bcff0>])

# %%
c.data_sets.list(write_protected=True)
# Out:
# DataSetList([<cognite.client.data_classes.data_sets.DataSet at 0x18feb3bd1d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bd270>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bd3b0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bd4f0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bd590>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bd630>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bd6d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bd770>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bd810>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bd8b0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bd950>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bd9f0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bda90>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bdb30>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bdbd0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bdc70>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bdd10>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bddb0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bde50>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bdef0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3bdf90>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3be030>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3be0d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3be170>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x18feb3be210>])

# %%
c.assets.list(root=True)
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x18feb2c5710>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c7770>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c5fd0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c7af0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c58d0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c57f0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c7150>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c5630>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c59b0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c5550>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c5470>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c5390>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c52b0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c51d0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c50f0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c4670>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c4e50>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c4c90>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c4f30>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c4bb0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb2c4910>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba97cb0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba97850>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba975b0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba974d0>])

# %% [markdown]
# ### Iterate over the list

# %%
for data_set in c.data_sets:
    print(data_set.id) # do something with the data_set
# Out:
# 532492593814
# 3708248994472
# 8971087276716
# 14634448291637
# 22547179591127
# 23758930699440
# 26170037612757
# 32889565298826
# 39029267989058
# 39210236434027
# 40327729659769
# 48758153143218
# 49161542373901
# 53733012649311
# 58158657947049
# 58839366849857
# 74431833051045
# 77646949468688
# 80048191584507
# 85963087988610
# 86545673296094
# 88809449333750
# 91028975699979
# 99825339813632
# 104573554199652
# 106313613626018
# 111662049520578
# 121537981905445
# 132053933855106
# 140804500368758
# 143222670456404
# 145208858652069
# 146987707262722
# 168085293540831
# 169508147476936
# 169685299373191
# 179556465647798
# 197929698661134
# 198122773158762
# 199327379323816
# 206245056521975
# 206659101186366
# 207573897183612
# 215787008330337
# 216292905815470
# 235504890779413
# 245211532024983
# 246644328516666
# 248638948877491
# 252666839699577
# 257089475305167
# 262253023676364
# 265431403968007
# 269244871670358
# 270019166497168
# 270478968056738
# 276165573849325
# 279042604876042
# 280384459601303
# 282044034755572
# 284485188464391
# 285082936999171
# 286953708826887
# 300212271108879
# 302428767654888
# 304901974689240
# 314274225507819
# 315209024880568
# 319694119277473
# 321926613231193
# 322621260179540
# 327168443834829
# 328580403083325
# 329072658213138
# 332047216091763
# 334893065260762
# 339913999390152
# 342164539129005
# 343884367520567
# 351328956215406
# 351455938750371
# 351677402697202
# 351737611876309
# 353712872146981
# 356556244549877
# 360770756365631
# 361044291120590
# 361983842667871
# 365268718569230
# 366735187905526
# 367655503293353
# 371471186486047
# 371567262787826
# 373080082861177
# 374204154593058
# 376488702317880
# 382894356027718
# 8872099084183182
# 8875736125476488
# 8884586067829580
# 8885906891088429
# 8891137463101375
# 8892837693829416
# 8897004932475098
# 8900536827183903
# 8905717659831811
# 8910920545776774
# 8912108052353593
# 8912324595426775
# 8915127684162281
# 8931415933035631
# 8931807512379695
# 8936848950370922
# 8937288644036510
# 8940199088856110
# 8941192889025716
# 8947162472938037
# 8948212691025116
# 8951775410330662
# 8951987396216694
# 8956090836557690
# 8961104075527836
# 8972180296200736
# 8972707006396622
# 8973177218043550
# 8974549625418043
# 8982667033174558
# 8995961659611125
# 8996210909288140
# 9000161995369545
# 9005720873673750

# %% [markdown]
# When List is too big, then use the **chunk_size** parameter to get the list in chunks

# %%
for data_set_list in c.data_sets(chunk_size=5):
    print([x.name for x in data_set_list]) # do something with the list
# Out:
# ['TestDataset_pawara', 'pawel_world_info', 'my_example_dataset', 'world_info_jack', 'aleksander_my_example_dataset']
# ['Marie_world_info', 'Vlad1995c_example_dataset', 'Crístian2_world_info', 'Anjudata_set_1', 'world_info_jack']
# ['world_info_jack_11', 'world_info_jack', 'world_info_jack', 'jdavid87_example_dataset', 'world_info_Timi']
# ['1st level', 'my_name_example_dataset', 'my example', 'Sofie2000_world_info', 'world_info_mohsen']
# ['world_info_bhaskar', 'kiyoshi_world_info', 'world_info_jack_SAYAN', 'patrick1998_world_info', 'test']
# ['Prince_example_dataset', '1st level K', 'srish1800-IFSDB', 'world_info_jack', 'SofieHaug_example_dataset']
# ['Eduardo_example_dataset', 'jonathan_world_info', 'Srujana_world_info', 'my_example_dataset_wu', 'world_info_Stella']
# ['guilherme1990_exemple_create_python', 'ole_wammer_world_info2', 'smrsgv_info_jack', 'my_example_dataset_rodrigo', 'Test']
# ['my_example_dataset_temp', 'henrik_world_info', 'Ana2002NOR_TestDataset', 'third example', 'hanan_world_info']
# ['world_info_Pablo', 'Could anyone help remove this?', 'Fadi_example_dataset', 'GPaulo2000-IFSDB', '1stLevel']
# ['a_my_name_example_dataset', 'Vijaya New Dataset', 'Cornelius_world_info', 'gcbiotec_world_info', 'patrick1998_world_info']
# ['world_info_test_2', 'Ariel_HandsOn2_DataSet', 'world_info_jack', 'TestDataset', 'world_info_jack_sohaib']
# ['andy_test_example_dataset', 'world_info_jack', 'Luiz’s Personal Time series', 'mp_two_dataset', 'Test set']
# ['raj_world_info', 'ruben1984_example_dataset', 'Aneta1993_example_dataset', 'write-protected-data', 'joshan_world_info']
# ['{my_name}_world_info_jack', 'my_dataset', 'Yazan_example_dataset', None, 'krishna2001-Aveva.Net']
# ['vetle_world_test', 'Isabela2001_example_dataset', 'world_info_shiva', 'world_info_beni', 'rohit_1994_example_dataset']
# ['Alex_world_info', 'my example', 'ajha10_example_dataset', 'Shiva', 'TestNK']
# ['world_info_jack', 'Andreea_world_info', 'world_info_jack_novajj', '19890519_example_dataset', 'world_info_andrew']
# ['Rafli_world_info', 'irma_test', 'world_info_wei2010', '1st level-gs', 'my_example_dataset']
# ['henrik_world_info', 'heydar_worl_info', 'my_example_dataset_www', 'Gayathri_world_info', 'world_info_jack']
# ['Mostafa_world_info', 'dil_world_info', 'Maciukas_example_dataset', 'Andreea_world_info', 'Shiva']
# ['Simone_world_info', 'test_dataset8', 'my_example_dataset_vgr', 'world_info_areisdorf2', 'Maciej_world_info']
# ['second example', 'world_info_sha', 'saif_example_dataset', 'world_info_jack_as', 'world_info_sofie']
# ['gann2023-AvevaNet', 'Dzmitry1994_world_info', 'Vijaya_dataset', 'Tiago_world_info', 'camilla1996_world_info']
# ['Arpita2020-AvevaNet', 'PM_world_info', 'my_example_dataset23', 'world_info_krutip', 'mylittlepony_world_info']
# ['mylittlepony_world_info', 'Jorgen_world_info', 'blah_example_dataset', 'third example', 'world_info_chandc']
# ['world_info_jacksonG1994', 'my_example_dataset_006', 'hola', 'lsun_world_info', 'myworld_info_jack']
# ['DipeshYogi1994_world_info', 'MJ', 'faraz_alm', 'david_a_example_dataset', 'Trond_world_info']
# ['Rui77', 'Nick0000-IFSDB', 'world_info_kformella_example_dataset', 'second example', 'Naoki_example_dataset']
# ['Sofie2000_world_info', 'world_info_jackcity', 'my_example_dataset', 'my_example_dataset_1', 'world_info_suplenteeee']
# ['kimo_example_dataset', 'Medryl_world_info', 'world_info_andrew', 'amitoj_world_info', 'rsk_ds1']
# [None, 'world_info_jack', 'mlr__example_dataset', 'world_info_jack', 'world_info_jack_njj']
# ['world_info_ivar2', 'bojja_world_info', 'faisal_dataset', 'leandro1986_example_dataset', 'Mostafa_world_info']
# ['FirstnameBirthyear-AvevaNet', 'mfc', 'my_example_dataset_Him', 'Medryl_world_info', 'Dag1985_2_example_dataset']
# ['world_info_jack_suplente', "Scrubert's Spectacular World Info", 'Ivar1999_example_dataset', 'world_info_andrew', 'world_info_jack_Manv']
# ['rawan_world_info', 'Adriano2024_data_set', 'world_info_jack_99999999', None, 'world_data123']
# ['Rafli_world_info', 'christian_world_info', 'con_gtl_example_dataset', 'world_info_john', 'SIOD1980-AvevaNet']
# ['neil_example_dataset', 'Mudassir_world_info', 'gcbiotec_world_info1902A', 'mylittlepony_world_info', 'my_example_dataset_001']
# ['mohammed_al_safwan_example_dataset', 'world_info_adeeb', 'Medryl_world_info', 'my_example_dataset_test1', 'michti2000_world_info']
# ['world_info_mugless', 'Medryl_world_info', 'Mat1989_dataset', 'Mostafa_TestDataset', 'TatVF_world_info']
# ['name_example_dataset', 'my_example_dataset', 'third example', 'test_world_info', 'faisal_dataset']
# ['Rajat1985-IFSDB', 'JorgenAa_world_info', 'my_example_dataset', 'muhammad_jb_world_info_example_dataset', 'lucas2000-ds']
# ['FirstnameBirthyear-AvevaNet', 'world_info_jack_mm', 'dalvania_world_info', 'newworld_info_jack', 'chand_world_info']
# ['Sofie2000_world_info', 'Tetsu_example_dataset', 'world_info_jack', 'wu_world_info', 'world_data']
# ['Mudassir_world_info', 'neil_v_world_info2', 'Marcos81-6._world_info', 'sindre_world_info', 'dan_1979_example_dataset']
# ['2nd level', 'world_info_timo', 'teodor_world_info', '2nd level', 'juan_world_info']
# ['Ruslan_world_info', 'world_info_Kush', 'emmab_world_info', 'world_info_jack', 'Juan Alvarado world info']
# ['world_info_academy2', 'pawel-test-dataset', 'second example', 'hmnasri-CDF3', 'world_info_andrew']
# ['smart-home-dataset', 'world_info_jack', 'angelica_world_info', 'Sameer1980_example_dataset', 'saif_world_info']
# ['camilla1996_world_info', 'joshan_world_info', 'Crístian_world_info', 'poc_example_dataset', 'Elcio19620805hands-on_world_info']
# ['DeepEnd_world_info', 'kimsb_world_info', 'JorgenAa_world_info', 'Mohamed_example_dataset', 'caroline_f_world_info']
# ['my_example_datasetcas', 'vinicius_peres_world_info', 'world_info_kailash', 'lxq_example_dataset', 'second example']
# ['Simone_example_dataset', 'Mikalay1991:my_example_dataset', 'jeanarnaudritouret_example_dataset', 'heman_dataset', 'Elciocs1962hands-on_world_info']
# ['world_info_wwu_H2', 'frendi_world_info', 'Diana_world_info', 'world_info_1991_2', 'clement_world_info']
# ['john_world_info', 'donkey_example_dataset', 'world_info_jack', 'sharizan1981_dataset2', 'my_example_dataset_Long']
# ['Ariel_example_dataset', 'my_example_dataset', 'world_info_takei2', 'world_info_kruti', 'Simone_world_info']
# ['gayathri_world_info', 'juan_world_info', 'varun_example_dataset', 'prefix', 'rsinha3 world info']
# ['Saurabh_world_info', 'JOS_world_info', 'Reynald2025_example_dataset', 'lia_world_info', 'MS_202502']
# ['Reynald1971_world_info', 'wael__world_info', 'christian_world_info', 'LNDR_world_info', 'world_info_jack']
# ['world_info_jack', 'Itika_Dataset', 'nikos_world_info', 'Medryl_world_info', 'teodor_world_info']
# ['santobedi_example_dataset', 'my_example_dataset-test', 'ag_singh_example_dataset', 'Mostafa_example_dataset', 'my_name_example_dataset']
# ['Arya_example_dataset', 'world_info_jack', 'saif_world_info', 'Jashoda_example_dataset', 'Henrik_world_info']
# ['Alq1997-AvevaNet', 'world_info_jack_JGK', 'Hariharan_world_info', 'Dipesh1994_world_info', 'world_info_jack']
# ['world_info_sendil', 'world_info_juju', 'Srujana_world_info', 'world_info_jader', 'EmiliesDS_v3']
# ['Marsilius_example_dataset', 'world_info_nick', 'Ravi_World_info3', 'dunham_world_info', 'Mohamed1996']
# ['Jorgen_world_info', 'world_info_jack', 'world_info_wwu', 'world_info_jack', 'world_info_jack']
# ['SampleDataset23', 'Maksym1981-1-dataset', 'my_example_dataset11', 'Ajit1992-IFSDB', 'amel_world_info_jack']
# ['Emilie_world_info', 'test_equip', 'abhi_example_dataset', 'elize_world_info', 'Timi_dataset1']
# ['Anil999_example_dataset', 'my_example_dataset', 'world_info_jack', 'world_info_jack', 'Shota_example_dataset']
# ['John7638', 'TestDataset_pawra', 'SofieKY_example_dataset', 'world_info_Ana2', 'world_info_shaheen']
# ['grobb_ho_dataset', 'first level', 'kiyoshi_world_info', 'saif_world_info_simple', 'JH 1st level']
# ['aarifov_world_info', 'world_info_mi', 'subodh_world_info', 'Jos_example_dataset', 'Shaurya_DataSet']
# ['Ahmad1997-ds', 'Zed_example_dataset', 'Vijaya New level', 'abhishekmaity1997_example_dataset', '1world_info_jack']
# ['andrew_world_info', 'afrendi_world_info', 'DP_TestDataSet2', 'NKTest123', 'akhilppujyamdataset']
# ['1st level', 'Vijaya level', 'mylittlepony_world_info', 'world_info_jack02', '111st level']
# ['wu_world_info', 'third example', 'Muddassirmm1', 'world_info_jack', 'christian_world_info']
# ['PTC_example_dataset', 'fj_world_info', 'joshan_world_info', 'kaminari_world_info', 'ruben_world_info']
# ['test_43_example_dataset', 'world_info_jack', 'world_info_jack', 'lala_level', 'my_example_dataset_abu']
# [None, 'jd1980-AvevaNet', 'my_example_dataset', 'world_info_Sofie', 'disha_world_info_jack']
# ['Amin1987-ds', 'world_info_jack', 'clement_world_info', 'my_example_datasetmm', 'yahya_world_info']
# ['third example', 'sujit_dataset', 'Mudassir_world_info', 'Jonluca_world_info', 'world_info_jack_pavan']
# ['test1', 'donkey_world_info', 'world_info_jack_1337', 'Srujana_world_info', 'world_info_jack_1964']
# ['JohnS1984_world_info', '2nd level', 'my_kimo_example_dataset', 'jeanarnaudritouret_world_info', 'world_info_jack']
# ['jeanarnaudritouret_2_example_dataset', 'saif_world_info', 'BrienWorld_info', 'daniel_world_info', 'csv']
# ['yeshwanth_example_data', 'world_info_jack', 'Elcio19620805N_section_problems_dataset', 'world_info_jack_t', 'world_info_jack_ass']
# ['world_info_ricardo', 'Arpita2021-IFSDB', 'pavko_example_dataset', 'christian_world_info', '3st level']
# ['world_info_mi2', 'mikita_world_info_jack', 'Mostafa_world_info', 'vsa_name_example_dataset', None]
# ['world_info_jack', 'erick_world_info', 'Gpd2000_example_dataset', 'manssari_world_info', 'NKTest']
# ['vgr_world_info', 'world_info_Aliii', '_world_info', 'Mallesh1993-AvevaNet', 'world_info_sameer1980']
# ['world_info_test_222', 'Jorgen1990_example_dataset', 'world_info', 'ck_world_info', 'Aneta_example_dataset']
# ['Cornelius_world_info', 'Kdunham_example_dataset', 'world_info_jack', 'emma_world_info', 'pavan1978-AvevaNet']
# ['Mudassir_world_info', 'name', 'Ravi_World_info3', 'Juan2001_world_info', '11st level']
# ['testds', 'my_example_dataset', 'daniel_world_info', 'my_example_dataset2', 'Shaurya_999']
# ['SumeetSingh_world_info', 'world_info_jack', 'Ivar2000_world_info', 'Saurabh_world_info', 'srish18001-IFSDB']
# ['juan_world_info.232', 'my_example_dataset2', 'grrr109 test data set name', 'shawn_ts', 'world_info_jack']
# ['world_info_abhinav', 'Mostafa_world_info', 'Simone_world_info', 'world_info_jack', 'PM_world_info']
# ['Amisha2001-AvevaNet', 'Arya_World_Info', 'GCH_world_info', 'my_example_11_dataset', 'world_info_jack']
# ['world_info_jack', 'Abiinfojack', 'ahmad_world_info', 'wael__world_info2', 'tfrendi_world_info']
# ['my example', 'DeepEnd_example_dataset', 'world_info_jack', 'world_info_jack', 'FirstnameBirthyear-IFSDB']
# ['third example', 'world_info_amitoj', 'kailash193-Avevanet', 'world_info_jack_121', 'michti2000_world_info']
# ['srujana_world_info', 'world_info_maksym1981_1', 'Aliwafasolv', 'irma_test', 'world_info_douglas']
# ['world_info_jack', 'world_info_fabiano', 'john_example_dataset', 'wellington1983_example_dataset', 'Akshay1993-cdm']
# ['world_info_abhinav', 'world_info_WillianGoulart1994', 'srujana_world_info', 'my_example_dataset', 'Yining1974-IFSDB']
# ['world_info_runaro', 'world_info_jack', 'prefix_new_example_dataset', 'my_name_example_dataset', 'EH_world_info3']
# ['world_info_jack', 'ruben_world_info', 'Jason1990_world_info', 'mylittlepony_example_dataset', 'world_info_halit']
# ['DeepEnd_world_info', 'Hasan_Hindi_example_dataset', 'sebastian_srikanth_example_dataset', 'Srmk_world_info', 'Sofie00_world_info']
# ['world_info_jack3', 'manolo_world_info', 'mylittlepony_world_info', 'my_example_dataset', 'my_example_dataset_x']
# ['world_info_christian1980', 'heydar_worl_info', 'dpg_world_info', '_world_info', 'world_info_jack']
# ['1st level', 'Elcio19620805_section_problems_dataset', 'ariel_world_info', 'my_abhi_dataset', 'Aman1997-AvevaNet']
# ['rdb_example_dataset', '_world_info', 'Laura_world_info', 'my_test_dataset', 'abhi_world_info']
# ['my_example_dataset', 'world_info_jacksonWG1994', 'world_info', 'ruben_world_info', 'world_info_jack']
# ['HydP2023', 'henrik_world_info', 'world_info_giovanna', '2nd level', 'Ravi_example_dataset']
# ['my_example_dataset_par', 'pkumar105_example_dataset', 'camilla_example_dataset', 'rafael_marques_example_dataset', 'Yahya1991-AvevaNet']
# ['BRA_example_dataset', 'Marie_world_info', 'world_info_marissa', 'E_example_dataset', 'my_name3_example_dataset']
# ['christian_world_info', 'cc_my_example_dataset', 'world_info_academy', 'my_example_datasetca', '1st level_m']
# ['world_info_jack', 'breno_word_info', 'rdb_world_info', 'EH Dataset', 'sebastian1999_world_info']
# ['Henrik_world_info', 'Muhammed_Muddaththir_world_info', 'salifu83_example_dataset', 'yoshi_world_info', 'dawei_world_info_jack']
# ['amna_example_dataset', 'world_info_tb11', 'luiz1987_example_dataset', 'saif_world_info', ' my_name_example_dataset']
# ['name', 'world_info_jack', 'world_info_jack_hv', 'Maciej_world_info', 'world_info_jack']
# ['world_info_jack', 'jayme_world_info', 'world_info_jack', 'world_info_jack', 'christian_world_info']
# ['world_info_mfc', 'Shiva', 'irma_test', 'srmk', 'rune57-worldinfo']
# ['my_veryown_dataset', 'ariel_world_info', 'world_info_jack2', 'montadahar:my_example_dataset', 'mylittlepony_world_info']
# ['Henrik1999_world_info', 'DeepEnd_world_info', 'delete_me', 'ds1', 'meher']
# ['johnzhu-ds', 'abhishek_rai_example_dataset', 'first level', 'my_test_ds', 'world_info_jack_daniel']
# ['SofieKY_world_info', 'my_work_example_dataset', 'xq_world_info', 'world_info_sid', 'jujus_dataset']
# ['mfc_world_info', 'christian_world_info', '1st level_m', 'gabor_world_info', 'henderson_world_infov2']
# ['world_info_jack2', 'tachiki_example_dataset', 'Ricardo_example_dataset', 'world_info_jj', 'anj_example_dataset']
# ['tom_world_info', 'nick_world_info', 'my example', 'my_example_dataset', 'rena1990_world_info_jack']
# ['Saidatul1995_world_info', 'legit_dataset', 'Guilherme_example_dataset', 'mauricio2_example_dataset', 'world_info_jack']
# ['PM_world_info', 'rsinha_iom', 'Simone_world_info', 'kliang-test-ds', 'Rodrigo1997_example_dataset']
# ['Krystal1986-AvevaNet', None, 'muygurworld_info', 'elias1998_example_dataset', 'world_info']
# ['Laura_world_info', 'ds_2', 'asha_world_info', 'Mark303-AvevaNet', '3rd_level']
# ['saif_world_info', 'maryam_example_dataset', 'world_info_medyo', 'my_name_vsa_example_dataset', 'Jaiprakash1988-AvevaNet.']
# ['second example', 'world_info_jack', 'Henrik1999_world_info', 'Marcos81.5._world_info', 'PM_world_info']
# ['SumitB1998-IFSDB', 'LNDR_world_info_2', 'jonH_world_info', 'henrik_world_info', 'mojtaba_world_info']
# ['talal_world_info', 'name', 'jeeva_world_info', 'Mikalay1991:world_info', 'my_example_dataset_PM']
# ['ane_world_info', 'world_info_jack', 'ali_htx', 'Mostafa_TestDataset', 'Zacarias_example_dataset']
# ['JFH_world_info', 'FirstnameBirthyear-AvevaNet', 'world_info_GCH', 'Yazan_example_dataset', 'JP my_example_dataset']
# ['Kuni1969_example_dataset', 'Magnus1994-DS', 'Abdulmonim_World_info', 'world_info_kformella_1', 'Shaheen1985_example_dataset']
# ['prueba_example_dataset', 'VFMProject_ClientCompany_Roger', 'loiola_example_dataset', 'devano_example_dataset', 'Own_Create_dataset']
# ['phils_world_info', 'jackson_goulart2_example_dataset', 'DZ_world_info', 'Felipe_world_info', 'exerciseworld_info_jack']
# ['magnus_world_data', 'AM-Test', 'yuri1989_example_dataset', 'md_faraz', 'subham_world_info']
# ['irma_test', 'mx_example_dataset', 'world_info_jack_MS', 'muhammad_jib_world_info_example_dataset', 'world_info_jack']
# ['world_info_jack_name', 'Simone_world_info', 'world_info_jack', 'Adriano2024_101_world_info_level1', 'Raluca_world_info']
# ['world_info_jack', 'the_thing_example_dataset', 'world_info_afi', 'Ivar1999_world_info', 'muhammad_jibrill_world_info_example_dataset']
# ['MJ_WORLD', None, 'world_info_jack', 'Liatime_series', 'world_info_tim']
# ['world_info_diego', 'world_info_GCH', 'Simon_world_info', 'vetle_example_dataset', 'Roger_example_dataset']
# ['PM_world_info', 'Alex1984_example_dataset', 'world_info_afrendi', 'Valdemar_world_info', 'test_dataset2']
# ['Compressor1992-AvevaNet', 'viniaperes_world_info', 'Rodrigo1997_world_info', 'saif_world_info', 'world_info_mark304']
# ['world_info_jack', 'world_info_1991_3', 'irma_test', 'world_info_andreea1', 'world_info_ole2']
# ['Jorgen_world_info', 'Him2_dataset', 'Marie_world_info', 'Hasan Hindi World Info', 'world_info_jack_new']
# ['Jader', 'my_example_dataset', '14_world_info_jack', 'world_info_jack_YDJ2025_1', 'jz_world_info']
# ['world_info_jack2222', 'joshan_world_info', 'Medryl_world_info', 'Alex_example_dataset', 'jeeva_world_info']
# ['MRosado_world_info', 'Reynald2025_world_info_jack', 'FirstnameBirthyear-AvevaNet', 'my_example_dataset', '**milton_barbosa_world_info**']
# ['anik_example_dataset', 'dzmitry1991_world_info', 'test', 'gcbiotec_world_info2002B', 'kiyoshi_world_info']
# ['Mudassir_world_info', 'muhammad_jb_example_dataset', 'andreas_world_info', '2nd level', 'Abu_world_info']
# ['world_info_jack', 'rsinha world info', 'second example', 'world_info_antonio', 'aman1997-IFSDB']
# ['ariel_world_info', 'my_example_dataset', 'mauricio-world-info-test-exercise2', 'world_info_Luiz_Cruz', 'E_world_info']
# ['AshwinK_Tasks_example_dataset', 'Sumedh_Dataset', 'Ruslan_world_info', 'my_example_datasetq', '_world_info']
# ['Mikita1994-dataset', 'test_dataset1', 'NKTest123', 'Christian_world_info', 'grigorii_world_info']
# ['Function pipeline configuration', 'my_example_data_set', 'world_info_jack-1', 'erick_example_dataset', 'gokhe_example_dataset']
# ['Mohamed1996', 'JP_world_info', 'world_info_jack', 'Brien2World_info', 'Marie_world_info']
# ['Jonas_example_dataset', 'yesh4507', 'Ashwin_Tasks_example_dataset', 'erick_world_info', 'Saketh1991_data_set']
# ['varun_world_info', 'Dimple_example_dataset', 'NKTest1234', 'xiao_example_dataset', 'world_info_jack']
# ['world_info_jack_5', 'EH_world_info2', 'Henrik1999_world_info', 'Pablo1971-AvevaNet', 'world_info_Paris']
# ['ahmed_dataset', 'world_info_jack', 'world_info_kkk', 'Jader_example_dataset', 'world_info_jack']
# ['FirstnameBirthyear-AvevaNet', 'Joseph1999_world_info', 'Aranya_world_info', 'world_info_academy', 'changemy name']
# ['first level', 'lyuping_world_info_jack', 'meghna_world_info', 'third example', 'world_info_douglas']
# ['world_info_xyz', 'world_info', 'andersonpr1979', 'Yashwanth_data', 'Anil_world_info']
# ['GCH_world_info', 'world_info_jack', 'Kosuke_Miyazaki_example_dataset', 'TestDataset', 'Ravi_World_info']
# ['EmiliesDS_v2', 'aarne_world_info', 'Simon_example_dataset', 'Tat_world_info', 'srish1800-AvevaNet']
# ['world_info_jack', 'Jin_example_dataset', 'harry_world_info', 'my_example_dataset', 'michael_world_info']
# ['world_info_mfc3', 'world_info_ja', 'world_info_jack2_new', 'world_info_jack', 'Saidatul1995_world_info']
# ['world_info_jack', 'MS_202502', 'first level', 'DeepEnd_world_info', 'krny_world_info_jack2']
# ['world_info_jack', 'my_example_dataset', 'world_info_jack', 'NehaSingh_example_dataset', 'test2001_example_dataset']
# ['marissa_data_set', 'AndreasNordby_world_info', 'world_info_jackss', '1st lvl', 'christian_world_info']
# ['yuri_servedio_world_info', 'Aditya1999-AvevaNet', 'erik_world_info', 'muhammad_j_example_dataset', 'Lucas_example_dataset']
# ['Fred1_example_dataset', 'HA2023', 'samuel_example_dataset', 'sebastian1994_example_dataset', 'World info']
# ['1st level', 'Yahya1991-IFSDB', 'DipeshYogi_example_dataset', 'Aidar_world_info', 'world_info_jack7059']
# ['irma_test', 'michti2000_world_info', 'world_info_mm2', 'pax_world_info_jack', 'world_info_jack']
# ['Diana_test', 'abhay_world_info', 'Gaurav Rajurkar_world_info', 'name_sujit_example_dataset', 'aabbccdd_world_info']
# ['christian_world_info', 'prashant_example_dataset', 'LNDR-Data-Set', 'Marcus_world_info', 'world_info_camilla']
# ['my_example_datasettestzp', 'yougiyou2000-AvevaNet', 'agnes_world_info', 'Aidar_world_info', 'Michti2000_example_dataset']
# ['Aranya5_world_info', 'world_info_jack', 'lucas-2000-world_info', 'world_info_Thilak', 'mads_world_info']
# ['Nate1987_world_info_jack', 'magnus_world_info', 'world_info_jack', 'Abner_example_dataset', 'T_dataset']
# ['world_info_jack', 'third example', 'world_info_amel', 'world_info_jack', 'world_info_jack']
# ['Medryl_world_info', 'world_info_jack', 'third example', 'test-ak-ds-10oct-003', 'world_info_jack_555']
# ['world_info_jack', 'Simon_world_info', 'world_info_jack_sid01', 'world_info_jackG', 'cp_wells']
# ['Isabela_world_info', 'world_info_rsandrini', 'world_info_maksym1981_3', 'world_info_jack', 'test_dataset']
# ['world_info_Root_Assert_Error_Test_011', 'doble_example_dataset', 'kliang_world_info', 'Patrick1998-AvevaNet', 'world_info_sanyam']
# ['test_sensor_1', 'dataSet1demo', 'world_info_rew', 'Aranya2_world_info', 'grigorii_world_info2']
# ['world_info_jack', 'JAN_world_info', 'YuiNish', 'world_info_jack', 'jz_world_info']
# ['amelfrendi_world_info', 'world_info_jack_005', 'delete_me', 'EZhyzneuski world_info_jack', 'world_info_jack']
# ['1st level', 'g_ferrazzo_new_name_dataset', 'Andreea09', 'Crístian1_world_info', None]
# ['my_example_dataset', 'RSandrini_example_dataset', 'muhammad_jibril_example_dataset', 'yen_example_dataset', 'g_ferrazzo_HOE_1st_ds']
# [None, None, 'world_info_jack2', 'CaioCaio', 'mduque_world_info']
# ['toye_world_info', 'world_info_jack', 'ds_3', 'world_info_rod', 'greynoso71_world_info']
# ['fj_example_dataset', 'dpg2_world_info', '2nd level', 'Cornelius_example_dataset', 'world_info']
# ['EH_world_info4', 'my_name_takeshi_example_dataset', 'johannes_world_info', 'world_info_suplentee', 'my_name_example_dataset']
# ['Rafli_world_info', 'world_info_varunn', 'daniel_world_info', 'world_info_Vipul', '3th level-gs']
# ['xiaoniuzhang_world_info', 'patrick1998_world_info', 'pavko_world_info', 'yuri_servedio_2_world_info', 'Alan1994_World_Info']
# ['kosuke_world_info', 'world_info_doug', 'Vijaya level', 'world_info_Root_Assert_Error_Test', 'world_info_jack_1990_aida']
# ['Sai1988-AvevaNet', '2nd level', 'world_info_med', 'Cognite', 'OscarVV_example_dataset']
# ['world_info_jack', 'SumeetSingh_world_info', 'Elize_example_dataset', 'tsk_my_example_dataset', 'henrik_world_info']
# ['faisal_world_info', 'pligarcia_example_dataset', 'vetle_world_info', 'henrik_world_info', 'Kushagra_1_world_info']
# ['Mudassir_world_info', 'Dag1985_example_dataset', 'GCH_world_info', 'Rostyslav1984-IFSDB', 'rsinha2_iom']
# ['world_info_jack', 'JP 1st level', 'antoine_example_dataset', 'jeanarnaudritouretcognite_world_info', '003Khobar_world']
# ['Alex1995_world_info', 'Ali_world_info', 'world_info_jack_23', 'world_info_jack', 'Hariharan_world_info']
# ['dasor_world_info', 'gabor_world_info', 'world_info_sky', 'world_info_moe7', 'Victor2001_world_info']
# ['AshwinK_example_dataset', 'jd1980-IFSDB', 'Pablo_Souza_Radix_example_dataset', 'henderson_world_info', 'second example']
# ['world_info_jack03', 'Sofie00_world_info', 'second example', 'Ivar1999_data_set', 'MS_202502']
# ['Mikalay1991:world_info', 'Maciej_world_info', 'heydar_worl_info', 'srish1800-AvevaNet', '4th level']
# ['hikaru_example_dataset', 'my_example_dataset_dw', 'dunham_world_info', 'Dzmitry_world_info', 'evg-1980_dataset']
# ['my_example_dataset', 'abhayA_world_info', 'rsk_dataset', 'world_info_shehan', 'world_info_muglessdurry']
# ['world_info_jack23', 'Laura_world_info', 'world_info_haziqs', 'roberto_example_dataset', 'world_info_jack']
# ['world_info_alex', 'Jorgen_world_info', 'ryan_world_info', 'world_info_daniel1991', 'Hachem_example1']
# ['world_info_jack_sohaib1', 'my_example_dataset_PJM', 'world_info_jack', 'world_info_jack', 'Balcos_world_info']
# ['irma_test', 'Miles_example_dataset', 'world_info_maksym1981', 'RI_world_info', 'my_example_dataset']
# ['my_date_example_dataset', 'Task_126_ds_python', 'my_name_example_dataset', 'world_info_teste', 'Ruslan_world_info']
# ['world_info_jack', 'Govindraj1989-AvevaNet', 'Marcos81.1._example_dataset', 'wu2010_world_info', 'world_info_moe6']
# ['lucas-2000-ds', 'Mohammed1995', 'krishna2001-IFSDB', 'my-custom-dataset', 'Laura_world_info']
# ['Luca_world_info', 'my_example_dataset', 'cristian', 'EH_world_info5', 'LC_1st level']
# ['Gaurav Rajurkar_world_info', 'srmk', 'Sample_Veda', 'uberlei_world_info_jack', '1st level']
# [' my_name_example_dataset', 'shigeyuki_example_dataset', 'my_cool_example_dataset', 'Ravi_dataset2', 'world_info_jack']
# ['world_info_jack_Manvendra', 'Vani_99-ds', 'saif_world_info', 'irma_test', 'yeshwanth_45']
# ['world_info_fma', 'Vani_1999', 'world_info_Sumeet', 'lord_odg_example_dataset', 'irma_test']
# ['Harsha2000-IFSDB', 'sofie_dataset', 'ola_world_info', 'lia_world_info', 'my_example_dataset']
# ['nick_world_info', 'SumeetSingh_world_info', 'world_info_chirag', 'my_example_dataset_nikhil', 'anil_ulchala_example_dataset']
# ['chand_world_info2', 'world22_info_jack', 'andreea', 'lsun_example_dataset', 'world_info_ivar']
# ['world_info_vero', 'juan_world_info', 'faraz_alam', 'my example', '2nd level']
# [None, 'Aldo_world_info', 'dpg_example_dataset', None, 'Izabella_example_dataset']
# ['Abhishek_Rai_example_dataset', 'marius_world_info', 'Marie_world_info', 'second example', 'saif_world_info']
# ['ariel_world_info', 'world_info_jack', 'world_info_sagar', 'VFMP_Sf05ynhm0v', 'world_info_jayanth']
# ['Maria_world_info', 'DP_TestDataSet', 'ROHIT2000_example_dataset', '2nd level_m', 'SumeetSingh_world_info']
# ['vetle_world_info', 'Nishant_example_dataset', 'world_info_jack', 'my_name_takei_example_dataset', 'my_name_example_dataset']
# ['Jorgen_world_info', '5th level', 'mauricio-world-info-test-exercise', 'ariel_world_info', 'world_info_ruben1984']
# ['world_info_new2', 'world_info_jack_kk', 'David19652_world_info', 'world_info_camilla', 'HA2023']
# ['joshan_world_info', 'christian_world_info', 'shubham8_example_dataset', 'Marie_world_info', 'ajin_example_dataset']
# ['Juan2001_world_info', 'Kei1990-world_info_jack_example_dataset', 'world_info_new', 'world_info_abnermendes', 'Alfredo2_world_info']
# ['world_info_academy', 'AP_example_dataset', 'world_info_jack', 'Elcio196208hands-on_world_info', 'V__world_info']
# ['mohsen_example_dataset', 'olav_world_info', 'Ravi_World_info2', 'Tatsiana1994test', 'World_info_ROHIT2000']
# ['my_name_example_dataset', 'jsc_world_info', 'world_info_gcbiotec', 'pratish_integrate_dataset', 'test_dataset4']
# ['my_example_dataset_wu_2', 'Jose_example_dataset', 'xxxxx_DP_TestDS', 'TestDataset', 'maude_world_info']
# ['Harsha2000-AvevaNet', 'world_info_lama', 'jz_world_info', 'world_info_jack_003', 'Yuri1989']
# ['jose_siq_example_dataset', 'world_info_jack', 'PM_world_info', 'rawanaltaha_world_info', 'world_info_maciej1977-v3']
# ['Vaishnavi_example_dataset', 'world_info_Goulart1994', 'world_info_jack', 'yaswanth_world_info', 'Vivek_world_info']
# ['Sanyam_example_dataset', 'world_info_jack', 'world_info_jb', 'fjpg_world_info_jack', 'Marie_world_info']
# ['world_info_jack_1', 'world_info_jacktestfdafsdf', 'LSM_example_dataset', 'Simon_world_info', 'world_info_ln']
# ['ole_wammer_world_info', 'LGH1', 'world_info_jack', 'world_info_H', 'world_info_jack_new']
# ['222nd level', 'Arya_World_Info', 'teodor_world_info', 'GCH_world_info', 'gs_world_info']
# ['tsk_world_info', 'my_example_dataset', 'irma_test', 'irma_test', 'world_info_asade']
# ['Shaurya_2023-ds', 'henrik_world_info', 'world_info_jack', 'my_example_dataset1', 'Aneta1993_world_info']
# ['Simon_world_info', 'world_info_rui', 'world_info_jack', 'JOS_world_info', 'world_info_camilla2']
# ['gcbiotec_world_info2002A', 'world_info_SumitB', 'pratica_pet_world_info', 'jeeva_world_info', 'GCH_world_info']
# ['my_example_dataset', 'my_test_dataset', 'camilla1996_world_info', 'PM_world_info', 'Rafli_world_info']
# ['19910118_example_dataset', 'clement_world_info', 'world_info_jack_lundemo', 'neil_world_info', 'DP_TestDS']
# ['Srujana_world_info', 'GPD2000_world_info', 'hmnasri_world_info', 'world_info_jack', 'Henrik1999_world_info']
# ['Marcos81_example_dataset', '_world_info', 'yousef_world_info', 'dylan_example_dataset', 'world_info_jack']
# ['world_info_maxim', 'Aranya_example_dataset', 'as_dataset1', 'dls_example_dataset', 'Anshu_world_info']
# ['Shirin_world_info', 'Rafli_world_info', 'henrik_world_info', 'Sudil1997', 'LauraS_example_dataset']
# ['jn_example_dataset', 'world_info_ning', 'cristian_example_dataset', 'sid1974', 'BrienWorld_info']
# ['hmnasri-CDF', 'caroline_f_world_info2', 'Aranya_world_info', 'world_info_jack', 'world_info_jack']
# ['michti2000_world_info', 'world_info_haziq', 'nf_world_info_jack', 'my_example_dataset_saketh', 'michti2000_world_info']
# ['Simon_world_info', 'my_ds', 'christian_world_info', 'world_info_andrew', 'heman_2nd_dateset']
# ['my_name_f386572f-0bc9-4a63-afe7-148b1a839c34', 'my_world_info', 'Aqilah1993-AvevaNet', 'TestDataset', 'GCH_world_info']
# ['world_info_jack', 'fredrik2000_example_dataset', 'mylittlepony_world_info', 'work_info_jack', 'world_info_moe4']
# ['lia_example_dataset', 'world_info_kaminari', 'second example', 'world_info_jack_002', 'kiyoshi_world_info']
# ['my_example_dataset', 'my_example_dataset_k', 'jeanarnaudritouretcognite_example_dataset', 'YS_example_dataset', 'henrik_world_info']
# ['second example', 'world_info_jack_test1', 'saif_world_info', 'Dzmitry1994_world_info', 'victor1_example_dataset']
# ['Tat2_world_info', 'Alf57_world_info', 'saif_world_info', 'Luiz_Cruz_example_dataset', 'Aidar_world_info']
# ['world_info_jack', 'Saurabh_world_info', 'E_world_info', 'test_dataset7', 'world_info_jack_111']
# ['world_info_orjanm', 'ConocoPhillips_Sensor', 'dp1998', 'world_info_anto', 'Saurabh_world_info']
# ['hamdi_world_info', 'Marie_world_info', 'world_info_academy', 'my_example_dataset_sebastian1999', 'anju_trial_dataset']
# ['Adriano2024_example_dataset', 'world_info_jack', 'sanjana_world_info', 'AElena_world_info', 'alex1995_example_dataset']
# ['elias_world_info', 'gustavo_world_info', 'Simon_world_info', 'world_info_jack', 'world_info']
# ['DeepEnd_world_info', 'alex_world_info', 'saif_world_info', 'marius_world_info', 'world_info_LauraS']
# ['mt9_example_dataset', 'Brien2World_info', 'muhammad_jibril_world_info_example_dataset', 'world_info_Hachem', 'jeeva_testing']
# ['saif_world_info', 'world_info_suplente', 'cdf_training_fjpg2', 'world_info_jack_rack', 'ownworld_info_jack']
# ['palvo_world_info', 'Ravi_World_info4', 'yoan_world_info', 'Jorgen_world_info', 'Sofie2000_world_info']
# ['njf_world_info_jack', 'my_example_dataset', 'DeepEnd_world_info', 'michti2000_world_info', 'Custom Create Dataset']
# ['Luiz_Cruz_world_info', 'world_sheep_4', 'Rushikesh_example_dataset', 'lucas_2000_example_dataset', 'Paniz_example_dataset']
# ['Brien_example_dataset', 'Raisa_example_dataset', 'SumeetSingh_world_info', 'world_info_dima', 'Aidar_world_info']
# ['world_info_test', 'world_info_jack329', 'world_info_jack', 'demo23', 'my_example_dataset']
# ['world_info_jack', 'lama1_example_dataset', 'Juan2001_example_dataset', 'Marie_world_info', 'my_name_is_taken_example_dataset']
# ['world_info_jack_rohit', 'BrienWorld_info', 'pallab_example_dataset', 'TestDataset', 'Valhall OID']
# ['Maciukas_world_info', 'Teste_Teste_Teste', 'world_info_jack', 'world_info_jack_rohit1994_example_dataset', 'world_info_jack']
# ['my example', 'my_example_dataset_js2001', 'Istvan_world_info', 'DipeshY_world_info', 'tsk_world_info']
# ['Juan_Caires_example_dataset', 'Nhao_example_dataset', 'Yazan_example_dataset', 'my_name_example_dataset', 'lsun_example_dataset2']
# ['gabor_world_info', 'leann1993_world_info_jack', '**milton_barbosa_world_info**', 'Medryl_world_info', 'elize_world_info']
# ['zhanat_world_info', 'my_example_datasetcs', 'sid1974-world_info', 'world_info', 'Alex_1979_example_dataset']
# ['Aneta_world_info', 'mikita_world_info', 'test_dataset3', 'my_example_dataset', 'world_info_jack']
# ['leandro1986_2_example_dataset', 'world_info_Ana1', 'srujana_world_info', 'HansGünter_example_dataset', 'my_example_dataset_ww']
# ['world_sheep_3', 'world_info_jac', 'Pavan1978-IFSDB', 'jeanarnaudritouret_world_info', 'MatiasRamsland_world_info']
# ['third example', 'Mark303-IFSDB', 'abhishek_rai_test', 'Sean1985_world_info', 'Vipul_example_dataset']
# ['2nd level_test', 'emma_example_dataset', 'JP 2nd level', 'world_info_jack', 'world_info_jack ']
# ['world_info_NK', 'world_sheep', 'irma_test', 'world_info_orjan', 'ds_4']
# ['pallab_world_info', 'PM_2nd level', 'GiovannaOctuber2003-AvevaNet', 'Jorgen_world_info', 'world_info_jack_name']
# ['1st lavel', 'felipef_example_dataset', 'world_info_john_3', 'GCH_world_info', 'marius_world_info']
# ['g_ferrazzo_test_tiy', 'world_info_maksym1981_2', 'world_info_takei', 'my_example_datasetEPC', 'Him3_dataset']
# ['world_info_jackdfdfdf', 'my_example_dataset', None, 'world_info_mugless', 'paco_example_dataset']
# ['anj_world_info', 'nathan_example_dataset', 'world_info_new3', 'Juan2001_world_info', 'my_example_dataset']
# ['my_name2_example_dataset', 'asha_world_info', 'world_info_jack_mm1', 'my_example_dataset_nick', 'SumeetSingh_world_info']
# ['Mudassir_world_info', 'toye_world_info', 'clayton_harlin_world_info', 'TestDataset', 'world_info_jack123a']
# ['rodrigo1997_world_info_jack', 'mauricio-world-info-test2-exercise', '1st level', None, 'Elcio196208_example_dataset']
# ['Ruslan_world_info', 'prefix_1_example_dataset', 'Laura_world_info', 'world_info_jack', 'world_info_jack_name']
# ['TestDataset', 'Training1-AvevaNet', 'PM_world_info', 'irma_test', 'world_info_jack']
# ['AbhayA_example_dataset', 'Simon_world_info', 'LUCAS_DMR_dataset', 'Ali2002_example_dataset', 'my_name___example_dataset']
# ['world_info_jdavid87', 'world_info_xiaozhang', 'world_info_jack_mariana', 'BrienWorld_info', 'world_info_sol']
# ['Zedchuu_example_dataset', 'world_info_jack', 'Medryl_world_info', 'Marie_world_info', 'PM_world_info']
# ['Marcos81>8._world_info', 'world_info_jack_Shirin', '2nd level', 'hanson1', 'josip_example_dataset']
# ['breno_word_info', 'Luiz_Cruz_LFLC_World_Info', 'world_info_YuiNish', 'Loguinha_example_dataset', 'world_infojac']
# ['santobedi1_example_dataset', 'PM_my_veryown_dataset', 'world_info_jack', 'Tat_dataset', 'world_info_jack_abhi']
# ['rs_my_example_dataset', 'world_info_jack_name', '2ndLevel', 'amolspawar_example_dataset', 'Anshul2024_PythonSDK_example_dataset']
# ['world_info_jack', 'my_name_example_dataset', 'christian_world_info', None, 'test_dataset6']
# ['Matthew1991_world_info', 'Matthew1991-AvevaNet', 'Benjy_world_info', 'Simon_world_info', 'world_info_sangubotla']
# ['jsc_example_dataset', 'pawel_world_info', 'Mudassir_world_info', 'Vipul_world_info', 'JohnS1984_example_dataset']
# ['myhk_example_dataset', 'world_info', 'my_example_dataset', 'third example', 'robin_example_dataset']
# ['neil_v_world_info', 'DP_TestDataSet1', 'Ariel_HandsOn_DataSet', 'world_info_academy', 'Henrique1991_example_dataset']
# ['Alan1994', 'Khobar2023-IFSDB', 'irma_test', None, 'my example']
# ['cornelius_info_world', 'Kush_world_info', 'rsk_ds1', 'my_example_dataset485', 'Ravi_World_info5']
# ['my_example_dataset', 'Ruslan_world_info', 'ali_world_info', 'Alex_1979_world_info', 'Laura_world_info']
# ['world_info_jack', 'world_info_rsk', 'my_example_dataset1', 'saif_world_info', 'Mikalay1991:world_info']
# ['my_example_dataset', 'hikaru_world_info1', 'Task_21_07_23', 'SumeetSingh_world_info2', 'world_info_jack_two']
# ['uberlei_example_dataset', 'second example', 'Aranya_world_info', 'Reynald_factory', 'aabbccdd_world_info']
# ['world_info_jack', 'Sofie2000_example_dataset', 'world_info_jack', 'Gerardo_world_info', 'TestDataset']
# ['henrik_world_info', 'Jorgen_world_info', 'world_info_jackP', 'lsun2_world_info', 'Ricardo_DataSet']
# ['world_info_chandc2', 'world_info_jack', 'ds_3', 'world_info_raluca', '2nd level']
# ['world_info_rsk1', 'Mudassir_world_info', None, 'world_info_jack_100', 'test']
# ['world_info_acaemy', 'world_info_moe1', 'Marcos_world_info', 'dalvania_world_info_3', 'Cornelius_world_info']
# ['Adriano2024-world_info_jack', 'my example dataset', 'jz_example_dataset', 'kiyoshi_world_info', 'PM_world_info']
# ['world_info_jack', 'world_info_jack_mm11', 'heron_carlos_example_dataset', 'ih_example_dataset', '2nd level']
# ['my_name_example_dataset', 'world_info_jack_101', 'E_world_info', 'Yining1979-AvevaNet', 'world_info_roberto']
# ['world_info_mm', 'Yazan_example_dataset', 'world_info_jack', '1st level Kruti', 'jon_world_info']
# ['Marcos81>7._world_info', 'third example', 'world_info_jack', 'world_info_bm', 'sagar_d_example_dataset']
# ['Mudassir_world_info', 'irma_test', 'GustavoTostes_world_info', 'my_example_dataset3', 'lyuping_example_dataset']
# ['Maciej_example_dataset', 'world_info_jack', 'cp_wells', 'world_info_nlm', 'Juan2001_world_info']
# ['Nick0000-AvevaNet', 'marie_example_dataset', 'clement_world_info', 'my_example_dataset', 'world_info_jack']
# ['my_example_datasetcasa', 'dasor_world_info', 'javid_world_info', 'world_info_marissa2', 'world_info_nlm_2']
# ['renan_example_dataset', 'world_info_jack', 'Marie_world_info', 'Maria_world_info', 'my_name']
# [None, 'world_info_jack', 'world_info_jack_0', 'EH_world_info', 'Abi1234567_example_dataset']
# ['gabriel1986_dataset', 'dunham_world_info', 'world_info_moe5', 'Henrik1999_world_info', 'jz_example_dataset_1']
# ['PTC_world_info2', 'world_info_jason', 'my_example_dataset197', 'world_info_jack', 'Simone_world_info']
# ['world_info_jack', 'Luiz_Lima_Cruz_world_info', 'world_info_jonathan', 'christian_world_info', 'alex_world_info']
# ['my_example_dataset', 'Naveen_example_dataset', 'test_dataset9', 'mw_world_info', 'third example']
# ['Mudassir_world_info', 'world_info_jack', 'world_info_jack', '2nd level', 'Fred2_example_dataset']
# ['my_example_dataset_Manvendra', 'world_info_jack1', 'world_info_jack', 'kiyoshi_world_info', 'world_info_Charles']
# ['world_info_jackson1994', 'Morten_world_info', 'world_info_ravi', 'Test', 'world_info_jack_mm113']
# ['world_info_jack', 'my_example_dataset_gui', 'sam_world_info', 'world_info_jack', 'masanori_world_info']
# ['DeepEnd_world_info', 'world_info_abhay', 'Gushino_world_info', 'Trial_Itika_Dataset', 'abhishek1996_dataset']
# ['joshan_world_info', 'tjk_example_dataset', 'world_info_academy', 'Istvan_dataset', '1st level']
# ['raji_example_dataset', 'subodh_dataset', 'Hasib1994-AvevaNet', '2nd level-gs', 'world_info_jack_99']
# ['world_info_jack', 'my_example_dataset', 'Simone_world_info', 'hest_example_dataset', 'JOS_world_info']
# ['Sumit1998-AvevaNet', 'Test_DS', 'my_example_dataset_2', 'dasor_world_info', 'gcbiotec_world_info99']
# ['joshan_world_info', 'Luis1977_world_info', 'nexus_example_dataset', 'global', 'masanori_dataset']
# ['world_info_jack_Ak', 'Ali-97-AvevaNet', 'zhanat_example_dataset', 'joar_example_dataset', 'Mudassir_world_info']
# ['Raluca_world_info', 'jeanarnaud_world_info', 'tutorial_name', 'world', 'world_info_jack']
# ['Henrik1999_world', 'world_info_wwu', 'Brien2World_info', 'sanj_world_info_', 'TSPL_Data']
# ['Elciocs1962xyzhands-on_world_info', 'ariel_world_info', 'world_info_jack_eb', 'world_info_jack', 'michti2000_world_info']
# ['world_info_jack22222', 'Haroldo_dataset', 'kkkkiii_example_dataset', 'Marcos81.3._world_info', 'world_info_moe2']
# ['kiyoshi_world_info', 'Gerardo1989_example_dataset', None, 'blake_s_example_dataset', 'world_info_jack_sid']
# ['EmiliesDS', 'lean20273world_info_jack', 'world_info_jack', 'luiz_example_dataset', 'world_info_haziqah']
# ['world_info_jack', 'exercise_example_dataset', 'irma_test', 'world_info_jack', 'my_example_dataset_2']
# ['world_info_mark306', 'Aman_example_dataset', 'world_info_maciej1977', 'Stian1986_example_dataset', 'PM_world_info']
# ['Trond_world_info', 'pallabg_world_info', 'faris_world_info', 'Andrian_world_info', 'Jo_world_info']
# ['world_info_ole', 'heman_example_dataset', 'mojtaba_world_info', 'world_info_jack_YDJ2025', 'Lucas_ldmr_example_dataset']
# ['Valdemar_world_info', 'TestDataset', 'world_sheep_2', 'Muhammed_Muddaththir_world_info_t', 'Christian1994_example_dataset']
# ['my_name_ajit_example_dataset', 'anju_example_dataset', 'Aneta_world_info', 'JOS_example_dataset', 'my_example_dataset_003']
# ['juan_world_info.232', 'ariel_world_info', 'santobedi_1_example_dataset', 'my_example_dataset3a', 'world_info_kk']
# ['Saurabh_world_info', 'my_name_example_dataset', 'world_info_jayanth2', '_example_dataset', 'mohsen_world_info']
# ['my_example_dataset_aguiar', 'Anshul_world_info_jack', 'Nhao1_example_dataset', 'Teste_Teste_Teste', 'saif_world_info']
# [' my_name_example_dataset', 'my_name_example_dataset', 'Abhishek_example_dataset', 'ourworld_info_jack', 'world_SYS']
# ['Simon_world_info', 'E_world_info', 'world_info_danger82', 'E_world_info', 'Him_my_example_dataset']
# ['world_info_jack_jj', 'world_info_elize', 'my example', 'RK_example_dataset', 'my_name_example_dataset']
# ['world_info_jack_999', 'saif_world_info', 'christian_world_info', 'Akshay1993_dataset', 'Aidar_world_info']
# ['masanori_example_dataset', 'Gaurav Rajurkar_world_info', 'amin_dataset', 'kevin198_example_dataset', 'xiaozhang_world_info']
# ['Ana2002_TestDataset', 'world_info_adonis', 'my_name_takei1979_example_dataset', 'Renaud66_example_dataset', 'Islas1994_example_dataset']
# ['camilla1996_world_info', 'sharizan1981_dataset', 'jeanarnaud_world_info', 'palvo_world_info', 'sebastian_srikanth_world_info']
# ['no name for this dataset', 'world_info_jack', 'my_example_datasett', 'EH_example_dataset', 'PM_world_info']
# ['Nate1987_example_dataset', 'gabor_world_info', 'IvarW_example_dataset', 'third example', 'my_example_dataset']
# ['world_info_jack_Ayan', 'akshay1993_example_dataset', 'Vivek_example_dataset', 'world_info_jack', 'world_Info_Utt']
# ['irma_test', 'my example', 'world_info_jack', 'NKTestF', 'world_info_jack']
# ['alex_world_dataset', 'NKTest1234', 'third example', '1st', 'FirstnameBirthyear-AvevaNet']
# ['manolo', 'JH 2nd Level', 'world_info_jack', 'colin1985_world_info', 'henrik_world_info']
# ['1337_hello_world', 'JH 3rd Dataset', 'Aranya7_world_info', 'E_world_info', 'subham_dataset']
# ['Simone_world_info', 'E_world_info', 'henrik_world_info', 'test123', 'world_info_jack']
# ['Haroldo_world_info', 'third example', '22nd level', 'AliiwafaAlii_world_info', 'Aranya8_world_info']
# ['ecanencia_example_dataset', '005Khobar_world', 'test_example_dataset', 'ali_ht', 'world_info_icaro1993']
# ['2nd level K', 'henrik_example_dataset', 'Reynald2024_example_dataset', 'yuriserv_example_dataset', 'subham_sarangi_world_info']
# ['olav_world_info', None, 'YSSoh_world_info', 'my_dataset', 'world_info_jack_ilya']
# ['Ajit1992-AvevaNet', 'Nikkia world_info', 'Simon_world_info', 'kkkkii_example_dataset', 'my_example_dataset']
# ['Jo_example_dataset', 'saif_world_info', 'world_info_', 'world_info_jack', 'palvo_world_info']
# ['michael2024_example_dataset', 'Abdulmonim_World_info', 'Maciej_world_info', 'World_info_jkantam', 'Reynald2023_example_dataset']
# ['Kdunham2_example_dataset', 'world_info_suplenteee', 'Saurabh_world_info', 'world_info_afii', 'world_info_abhinav']
# ['Emilie_world_info', 'aabbccdd_world_info', 'world_info_msksym', 'jz-dataset', 'Simon_world_info']
# ['my_example_dataset1123121', 'Hasan Hindi Hands On DataSet Practice', 'world_info_jack_sachin', 'my_example_dataset23456', 'dayvid_work_info']
# ['PM_world_info', 'my_example_dataset_0', 'jcm_world_info_jack', 'henrik_world_info', 'world_info_Paul']
# ['heydar_worl_info', '22nd level', 'Alfredo2_world_info', 'world_info_jack', 'Fabiano1975_example_dataset']
# ['kiyoshi_world_info', 'Raluca_world_info', 'world_info_jube', 'Philips Dataset', 'Marcos81.4._world_info']
# ['mcduque_world_info', 'roop_dataset', 'myfirstlevel_H', 'BrienWorld_info', 'Jorgen_world_info']
# ['christian_world_info', 'World_Info_ynugroho2', 'First Level', 'joshan_world_info', 'irma_dev_dataset']
# ['world_info_jack', 'world_info_medy', 'Trond1973_example_dataset', '1st level', 'my_namee_example_dataset']
# ['mcduque_world_info', 'Aranya_world_info', 'Laura_world_info', 'world_info_jack', 'Valhall system 23 P&IDs']
# ['christian_world_info', 'Mohamed1996', 'Aranya9_world_info', 'Ben1980-AvevaNet', 'my_example_dataset_saurabh']
# ['Aranya1_world_info', 'Ana2002BRA_TestDataset', 'hydra_world_info', 'world_info_Root_Assert_Error_Test_001', 'world_info_jack']
# ['orjan_world_info', 'world_info_jack', 'yogi1996-asset', 'Joseph1999_world_info', 'testing_199']
# ['Haroldo_example_dataset', 'Felipe_example_dataset', 'Ruslan_world_info', 'victor_example_dataset', 'heydar_worl_info']
# ['Kush_myexample_dataset', 'Joseph1999_world_info', 'my_example_dataset1', 'Itika_Dataset', 'Ravi_World_info']
# ['Rafli_world_info', 'world_info_jack', 'GCH_world_info', 'KrzysztofF_example_dataset', 'gcbiotec_world_info1902']
# ['mauricio_example_dataset', '000Khobar_world', None, 'world_info_jack', 'pbuathong_example_dataset']
# ['Morten1988_dataset', 'montadharR_world_info_jack', 'ds_novajj', 'maude_world_info', 'Valdemar_world_info']
# ['bb_example_dataset', 'my_example_dataset', 'cp_wells', 'my_tagSDK._example_dataset', 'Alf58_world_info']
# ['k20250730_example_dataset', 'rena_1990_example_dataset', 'kliang_example_dataset', 'dalvania_world_info_2', 'Muddassirmm11']
# ['Aditya1999-IFSDB', 'andreas1997_example_dataset', 'ariel_world_info2', 'world_info_jack', 'world_info_jack_189490']
# ['Mikalay1991:world_info', 'world_info_jack_12', 'Rafli_world_info', 'crístian_example_dataset', 'orjan_example_dataset']
# ['Rajeev_WorldInfo', 'world_info_greynoso71', 'world_info_jack', 'Marcos81>99._world_info', 'lucas_world_info']
# ['Lucas1995_world_info', 'kp0428_dataset', 'world_info_jack', 'my_example_dataset_tim', 'world_info_Mugless']
# ['my_name_XPTO_example_dataset', 'world_info_satz', 'palvo_world_info', 'Elcio1962_example_dataset', 'my example']
# ['DSING', '2nd level', 'lama_example_dataset', 'santobedi1_2_example_dataset', 'andersonpr1978']
# ['world_infomy_name', 'my_example_dataset', 'yahya_world_info2', 'MED2024_example_dataset', 'world_info_aida_1990']
# ['world_info_jack', 'world_info_jack', 'world_info_Valdemar', 'MyTestNK', 'PTC_world_info']
# ['my_name____example_dataset', 'my_example_dataset', 'mfc_world_info', 'heron_carlos_world_info', '1st level']
# ['Kushagra_world_info', 'world_info_jack', 'christian_world_info', '004Khobar_world', 'MuglessDurry_world_info']
# ['world_info_jack', 'felipef_world_info', 'Jorgen_world_info', 'BrienWorld_info', 'bojja_srikar_world_info']
# ['my_example_dataset', 'meher_world_info', 'my_names_example_dataset', 'tim_world_info', 'Luca_world_info']
# ['HA2023', 'my_example_dataset_not_duplicate', 'my_dataset', 'ruben_world_info', 'john2_example_dataset']
# ['my_example_dataset', 'ariel_world_info', 'Joa_world_info', 'my_example_dataset-anto', 'saif_world_info']
# ['ariel_world_info', 'jeanarnaudritouret_world_info', 'SYS_example_dataset', 'Ali20022_example_dataset', 'gabe_example_dataset']
# ['sebastian_srikanth_world_info', 'world_info_jack', 'GPaulo2000-AvevaNet', 'Ravi_dataset', 'Luca_world_info']
# ['world_info_iii', 'world_info_mark303', 'LC_2nd level', '11st level', 'NKTestF']
# ['world_info_jackme', 'bojja_world_info', 'world_info_jack_k', 'world_info_jack_hp', 'felipef_world_info']
# ['my_example_dataset', 'world_info_islas1994', 'Aranya6_world_info', 'world_info_jack_anubhav', 'mauricio1984_world_info']
# ['Achilles_World Info', 'world_info_jack', 'DiogoFerreira1989_world_info', 'my_example_dataset_fh', 'gabor_world_info']
# ['Pavan1979_example_dataset', 'Ariel2000_HandsOn', 'michti2000_world_info', 'second example', '1st level_test']
# ['first level', 'Syl1982-AvevaNet', 'manolo_example_dataset', 'dawei_world_info_jack', 'Laura_world_info']
# ['vsangubotla1989__world_info', 'patrick1998_world_info', 'henrik_world_info', 'jkotynski_example_dataset', 'my_example_dataset333333']
# ['NKTest123', 'world_info_jackm', 'jay_example_dataset', 'valdemar_example_dataset', 'irma_test']
# ['my_name_example_dataset', 'vsa_example_dataset', 'world_info_jack', 'my example', 'Obeida_world_info']
# ['1st level', 'my_example_dataset_240311', 'vetle_world_test', 'sohab_dataset1', 'world_info_rafael_marques']
# ['TestDataset', 'jz_world_info', 'heydar_worl_info', 'AshwinK2_example_dataset', 'world_info_jack12']
# ['my example', '2nd level', 'adam1947_example_dataset', 'ane_example_dataset', 'world_info_test_22']
# ['world_info_jack157', 'world_info_Ana', 'kris99', 'E_world_info', 'E_world_info']
# ['Alfredo_world_info', '2nd level_m', 'my_example_dataset_agnes', 'world_info_jack', 'Adriano2024_101_world_info_level_1']
# ['world_info_jack_abhi1', 'renanlt_example_dataset', 'Aidar_world_info', 'world_info_wwu', 'world_info_jack']
# ['cdf_training_fjpg', 'BCG_example_dataset', 'world_info_asade1', 'Ajit1992-AvevaNet', 'Valeriya_world_info']
# ['vst_example_dataset', 'DP_TestDS', 'Gpd2001_example_dataset', 'world_info_jack', 'world_info_jack']
# ['_world_info', 'my_example_dataset_Obz', '001Khobar_world', 'Garcia_example_dataset', '002Khobar_world']
# ['My_Prefix_example_dataset', 'lucas_hc_example_dataset', '19051989_example_dataset', 'world_info_Gus', 'ermias_world_info']
# ['bentekassie_dataset', 'world_info_jack', 'christian_world_info', 'second example', 'jeanarnaudritouret_world_info']
# ['NKTestF', 'world_info_antonia', 'saif_world_info', 'world_info_jackq', 'world_info_jack_name']
# ['Ana_world_info', None, 'Rostyslav1984-AvevaNet', 'Maksym1981-IFSDB', 'hikaru_world_info']
# ['sindre_example_dataset', 'world_info_pal', 'my_example_dataset_sid', 'muhammad_j_world_info_example_dataset', 'yeshwanth_4545-ds']
# ['gk742_world_info', 'world_info_jack', 'Simon_world_info', 'Dzmitry1994_world_info', 'my_example_dataset']
# ['FirstnameBirthyear-AvevaNet', 'world_info_Pal', 'world_info_jack', 'michti2000_world_info', 'world_info_sai']
# ['Monica72-AvevaNet', 'Fred_example_dataset', '2nd level', 'world_info_jack', 'Luis1977-AvevaNet']
# ['world_info_tim2', 'my_name_1_example_dataset', 'my_example_dataset', '1st level', 'marissa_data_set']
# [None, 'Ayan_example_dataset', 'JorgenAa_world_info', '13_world_info_jack', 'mylittlepony_world_info']
# ['Hiral1982-IFSDB', 'Maksym1981-AvevaNet', 'my_example_dataset', 'Anshu_example_dataset', 'TestDataset']
# ['world_info_andrew', 'Achilles_World Info', 'jeanarnaud_world_info', 'test_dataset5', 'world_info_jack1_new']
# ['1st level', 'world_info_jack_sid2001', 'Test_dataset-vidhi', 'Monica72-IFSDB', 'NKTestF']
# ['meher_world_info', 'world_info_neck', 'caroline_f_example_dataset', 'world_info_jack_hv', 'CDF_Asset_DE_example_dataset']
# ['TestDataset', 'DmEnergy1983_example_dataset', 'VST_world_info', 'world_info_jack', 'Simon_world_info']
# ['Mohamed1996', 'Mudassir_world_info', 'my example', 'jz_example_dataset_2', 'world_info_xq']
# ['varun_example_dataset', 'camilla1996_world_info', 'world_info_jackz2', ' my_name_example_dataset', 'magnus_world_data']
# ['DeepEnd_world_info', 'Dzmitry1994_world_info', 'Renata_example_dataset', '1st level', 'DeepEnd_world_info']
# ['world_info_caio', 'bruno_marques_world_info', 'my_name_example_dataset', 'world_info_jack', 'Vani_sample']
# ['world_info_andreea', 'NKTestDS', 'fahmi_world_info', 'my example', 'Michail1981_example_dataset']
# ['udantha_dataset', 'christian_world_info', None, 'third example', 'dk']
# ['Jorgen_world_info', 'world_info_jack1222', 'kiyoshi_world_info', 'world_info_Root_Assert_Error_Test_003', 'world_info_jack']
# ['my_example_dataset22', 'abhishek001_world_info', 'mehmet1997_dataset', 'Elciocs1962abchands-on_world_info', 'SofieFH']
# ['Aliii_world_info', 'world_info_blake', 'Marie_world_info', 'srish1800-IFSDB', 'heydar_worl_info']
# ['Henrik1999_world_info', 'YDJ2025_example_dataset', 'Jan1975-AvevaNet', 'Testssss', 'world_info_jack_name']
# ['world_info_gustavo', 'yusuf1999_example_dataset', 'EdgarBeltran_example_dataset', 'world_info_jack', 'Rishay1997-AvevaNet']
# ['Raluca_world_info', 'world_info_wdj', 'Valeriya_world_info', None, 'Leandro_world_info']
# ['Vijaya-1998-ds', 'my_example_dataset_Marcos1995', 'second example', 'world_info_jack', 'jackson_goulart_example_dataset']
# ['world_info_andrew', 'third example', '2st lvl', 'mark303_example_dataset', 'world_info_jack']
# ['my example', 'world_info_jack', 'second example', 'PM_1st level', 'Maciej1977-DataSetAPITest']
# ['xiao_world_info', 'vetle_world_info', 'Rafli_world_info', '19910218_example_dataset', 'third example']
# ['Arijit_example_dataset', 'gaurav-1991-AvevaNet', 'irma_test', 'madina_dataset', 'michti2000_world_info']
# ['GCH_world_info', 'my_example_dataset', 'world_info_sendil', 'Christian_world_info', 'world_info_subham']
# ['test_ds', 'world_info_jack1111', None, 'vetle_world_info', 'h_world_info']
# ['krny_world_info_jack', 'Shubham26_example_dataset', 'world_info_jack_Manav', 'LenninPalacios1998-AvevaNet', 'dayvid_work_info']
# ['my_example_datasetD', 'Ana2002_TestDataset', 'Muddassirmm', 'DiogoFerreira1989_example_dataset', 'world_info_jack']
# ['TestDataset', 'hanson', 'world_info_andrew', 'yaswanth_world_info', 'world_info_Timi']
# ['henrik_world_info', ' my_name_example_dataset', 'my_example_dataset', 'my_example_dataset', 'Rushikesh2000_example_dataset']
# ['kailash_world_info', 'Marcos81>9._world_info', 'thomas_1996_example_dataset', 'my_example_dataset_w', 'lucas_mateus_world_info']
# ['world_info_mfc2', 'Loguinha_world_info', 'SumeetSingh_world_info', 'vetle_world_info', 'world_info_abner']
# ['2nd level', 'Zed_world_info', 'world_info_mark304', 'erick_world_info', 'srujana_world_info']
# ['mittin_example_dataset', 'Mudassir_world_info', 'Mikalay1991:world_info', 'Ruslan_world_info', 'Quoc_world_info']
# ['irma_test', 'joshan_world_info', 'third example', 'henrik_world_info', 'mduque_world_info']
# ['Dzmitry1994_world_info', 'Second Level', 'C-Assets', '1st level KrutiLtts', 'Ravi_World_info4']
# ['Mark303-IFSDB', 'Akeel_example_dataset', 'saif_world_info', 'alex_world_info', 'VFMP_TI0IDOdYbV']
# ['world_info_jack', 'christian_world_info', 'world_info_jack_test1', 'kzhao_example_dataset', 'varun_example_dataset']
# ['mauricio-test-world-info', 'world_info_moe', 'dls_example_dataset', 'Elcio1962hands-on_world_info', 'world_info_chand']
# ['my_example_dataset_srujana', 'Yahya_example_dataset', 'Saidatul1995_example_dataset', 'santobedi1_1_example_dataset', 'TestDataset']
# ['sohab_dataset', 'datasetSree', 'my_example_dataset_x', 'Rajat1985-AvevaNet', 'hmnasri-CDF2']
# ['Ayan_world_info', 'Ivar1999_data_set', 'Emilie_world_info', 'my_example_dataset', 'world_info_pat']
# ['world_info_jack_fred', 'my_example_dataset', 'Abi123456_example_dataset', 'varun_world_info', 'world_info_jack']
# ['Jose1_example_dataset', 'my_example_dataset', 'Mudassir65 DataSet Testing', 'subodh_world_info', 'world_info_jack_mm111']
# ['Hiral1982-Assets', 'gk74_example_dataset', 'my_example_dataset', 'world_info_kp', 'sendil1980_example_dataset']
# ['joshua_stanley_world_info', 'nk_1997_example_dataset', 'Valdemar_world_info', 'Aishwarya1996', 'faris9999']
# ['Maciukas_world_info', 'mj_name_example_dataset', 'world_info_jack', 'Paniz_world_info', 'Practice-JS2001']
# ['world_info_maciej1977-v2', 'my_example_dataset', 'krishna2001-AvevaNet', 'world_info_jack', 'my_example_dataset1']
# ['Abacus24_world_info_dataset', 'jz_world_info', 'Gus_world_info', 'world_info_jack_MMTEST', 'caio_world_info']
# ['world_info_jack', 'joshan_world_info', 'world_info_jack', 'world_info_jack', 'world_info_N1980']
# ['world_info_alex_n', 'world_info_l', '1st level', 'Disha_world_info_jack', 'cdf_upload_test']
# ['world_info_academy', 'world_info_jack', 'world_info_jorge', 'world_info_jack1', 'world_info_lama1']
# ['chandradeep1947-AvevaNet']

# %% [markdown]
# ## Searching in CDF
#
# - Search the CDF resource types
# - Filter the search results
#
# **Code Pattern**
#
# `client.<cdf_resource_type>.search()`

# %% [markdown]
# ### Fuzzy Search on one field

# %%
c.assets.search(name="Norway",limit=5)
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x18feba966d0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba967b0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba96890>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba965f0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba96510>])

# %%
c.time_series.search(name="North",limit=5)
# Out:
# TimeSeriesList([<cognite.client.data_classes.time_series.TimeSeries at 0x18feba960b0>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x18feba96270>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x18feba96430>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x18feba96350>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x18feba95b70>])

# %%
c.files.search(name="sheet")
# Out:
# FileMetadataList([<cognite.client.data_classes.files.FileMetadata at 0x18feb2a0e20>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb2a1150>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb271150>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb273c50>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb273550>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb273b50>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb273650>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb273250>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb273050>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb273150>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb272f50>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb273d50>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864050>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864150>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864250>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864350>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864450>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864550>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864650>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864750>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864850>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864950>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864a50>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864b50>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x18feb864c50>])

# %% [markdown]
# Similarly for sequences and events

# %% [markdown]
# `c.sequences.search(name="some name")`
#
# `c.events.search(description="some description")`

# %% [markdown]
# ### Multi-field fuzzy search

# %%
c.assets.search(query="Nor",limit=5)
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x18feba95fd0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba95710>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba95c50>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba96190>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba95630>])

# %% [markdown]
# ### Exact search on one field (e.g. name, description etc)

# %%
c.assets.search(filter={"name": "Canada"})
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x18feba958d0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba959b0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba957f0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba95a90>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba94bb0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba952b0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba95470>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba94c90>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba95550>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba94ad0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba949f0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba94910>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba94830>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba94750>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba94670>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba94590>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba943d0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba94210>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba94050>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba95010>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba94f30>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba951d0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feba950f0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb880050>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb880130>])

# %% [markdown]
# get all timeseries for the above asset

# %%
c.time_series.search(filter={"asset_ids":[8516698919785878]})
# Out:
# TimeSeriesList([<cognite.client.data_classes.time_series.TimeSeries at 0x18feb880590>])

# %%
c.events.list()[0].type
# Out:
# 'Volcanic activity'

# %%
# First get an example type to filter on
example_type = c.events.list()[0].type
# Filter the events of that type
c.events.search(filter={"type":example_type})
# Out:
# EventList([<cognite.client.data_classes.events.Event at 0x18feb5e3290>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e31d0>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e3110>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e3050>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2f90>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2ed0>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2d50>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2c90>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2210>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2690>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2390>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e25d0>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2090>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2510>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2450>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e22d0>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e1910>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e1850>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e28d0>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2990>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2a50>,
#            <cognite.client.data_classes.events.Event at 0x18feb5e2e10>])

# %% [markdown]
# ### Multiple filters in search function

# %%
c.assets.list(limit=5,data_set_external_ids=['world_info_academy'])
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x18feb8803d0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb880ad0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb8802f0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb8804b0>,
#            <cognite.client.data_classes.assets.Asset at 0x18feb880bb0>])

# %%
c.data_sets.list()

# %%
c.assets.list(root=True)

# %%
c.assets.search(name="San",filter={"parent_ids": [349354003007241]})

# %% [markdown]
# ### Filter asset search using Label Filter

# %%
from cognite.client.data_classes import AssetFilter

# %%
c.assets.search(name="Norway",filter=AssetFilter(labels=LabelFilter(contains_all=["cold-countries"])),limit=5)

# %%
c.assets.search(name="Can",filter=AssetFilter(labels=LabelFilter(contains_all=["cold-countries"])),limit=5)

# %% [markdown]
# ## Retrieve the CDF resource types and data
#
# ### Code Pattern
# `client.<cdf_resource_type>.retrieve()`
#
# `client.<cdf_resource_type>.retrieve_multiple()`

# %% [markdown]
# ### Retrieve the CDF resource types

# %% [markdown]
# single item - using id

# %%
c.data_sets.list()

# %%
# id of dataset
c.data_sets.retrieve(id=2238694842784134)

# %%
c.time_series.retrieve(id=2238694842784134)

# %%
import datetime
# id of timeseries
c.time_series.data.retrieve(id=658605450035112, start=datetime.datetime(2018,1,1), end=datetime.datetime(2018,2,1))

# %% [markdown]
# single item - using external_id

# %%
c.data_sets.retrieve(external_id = "world_info_academy")

# %% [markdown]
# multiple items - using ids

# %%
c.data_sets.list()

# %%
c.data_sets.retrieve_multiple(ids=[39210236434027, 145208858652069])

# %% [markdown]
# multiple items - using external_ids

# %%
c.data_sets.retrieve_multiple(external_ids=["test_dataset1", "test_dataset2","my_important_dataset"], ignore_unknown_ids=True)

# %%
from datetime import datetime
# Don't put a long datetime range, as it'll fetch all the raw datapoints, which can be huge
c.time_series.data.retrieve(external_id=['Nauru_population','Spain_population'],start=datetime(2000,1,1),end=datetime(2024,1,2))

# %% [markdown]
# ### Retrieve all items related to an asset

# %%
# get the asset object for "Europa"
asset_obj = c.assets.retrieve(id = 349354003007241)

# %%
asset_obj

# %% [markdown]
# Asset Subtree

# %%
c.assets.retrieve_subtree(id = 349354003007241)

# %% [markdown]
# Children

# %%
asset_obj.children()

# %% [markdown]
# Parent

# %%
asset_obj.parent()

# %% [markdown]
# Events

# %%
# get the asset object for "Italy"
asset_obj = c.assets.retrieve(id = 2689912833887590)

# %%
asset_obj.events(limit=-1)

# %% [markdown]
# Timeseries

# %%
# get the asset object for "Italy"
asset_obj = c.assets.retrieve(id = 2689912833887590)

# %%
asset_obj.time_series()

# %% [markdown]
# ### Retrieve data

# %% [markdown]
# #### Retrieve Raw Data

# %%
# Don't put a long datetime range, as it'll fetch all the raw datapoints, which can be huge for Raw datapoints
c.time_series.data.retrieve(id=239507005016003, end='now')

# %% [markdown]
# #### Retrieve Aggregated data

# %%
c.time_series.data.retrieve_dataframe(id=239507005016003,
                    end='1000w-ago',
                    aggregates=["average","sum"],
                    granularity="1h")

# %% [markdown]
# Retrieve latest datapoint before a particular time (last or any past time point)

# %%
c.time_series.data.retrieve_latest(id=239507005016003, before="5w-ago")[0]

# %% [markdown]
# ### Plot the data points

# %%
c.time_series.data.retrieve(id=239507005016003, end='1000w-ago').to_pandas().plot()

# %% [markdown]
# ### Download files

# %% [markdown]
# Download files to disk

# %%
files_list = c.files.search(filter={"uploaded":True},limit=5)
files_list

# %%
! mkdir files

# %%
c.files.download(directory="files", id=[202614441188439, 4009508514690241])

# %% [markdown]
# Download a single file to a specific path

# %%
c.files.download_to_path("files/test.svg", id=202614441188439)
