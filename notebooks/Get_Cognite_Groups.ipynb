# %% [markdown]
# # Copyright 2022 Cognite AS
#
# ## Import the Libraries and Modules

# %%
import sys
from pathlib import Path

# Add utils directory to path (resolve from project root)
utils_path = (Path("..") / "utils").resolve()
if str(utils_path) not in sys.path:
    sys.path.insert(0, str(utils_path))

from cognite_groups_export import export_groups

# Parameters (edit as needed)
# Set customers to a list (e.g. ["oxy-oog-dev"]) to fetch only those; None = all from CUSTOMER_CONFIGS.
# Profile and results are printed for each customer in the list.
customers = ["oxy-oog-dev"]
token_cache_dir = Path.home() / ".cognite" / "token_cache"
output_file = Path("groups_by_customer.xlsx")
show_profile = True
show_raw_capabilities = False
max_groups_preview = 3
verbose = True

# Single entrypoint call
dataframes_by_customer, output_path = export_groups(
    customers=customers,
    output_file=output_file,
    token_cache_dir=token_cache_dir,
    show_profile=show_profile,
    show_raw_capabilities=show_raw_capabilities,
    max_groups_preview=max_groups_preview,
    verbose=verbose,
)
# Out:
# Fetching groups for customer: oxy-oog-dev
# gio: https://login.microsoftonline.com/24df34ab-a358-4b62-ba14-e5dfb43b9d63/oauth2/v2.0/authorize?client_id=22352de2-1f0f-48a0-ab9a-de17bbd48675&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A53000&scope=https%3A%2F%2Faw-was-gp-001.cognitedata.com%2F.default+offline_access+openid+profile&state=qLXKIFYwADCrcivn&code_challenge=LtvcS7sOhhhv89bxX5OhjSuCsQqHZG2qzLC-5tQp12w&code_challenge_method=S256&nonce=2b1ef66ac43170f836130516767b926a0275578e11c2240007421326e4838143&client_info=1: Operation not supported
# User Identifier: kx-ut87k69sRB2pqrRzqZg
# Name: Joe O'Bryant
# Email: Joe_O'Bryant@oxy.com
# Full profile: {
#     "user_identifier": "kx-ut87k69sRB2pqrRzqZg",
#     "last_updated_time": "2026-02-18 07:06:13.003+00:00",
#     "given_name": "Joe",
#     "surname": "O'Bryant",
#     "email": "Joe_O'Bryant@oxy.com",
#     "display_name": "O'Bryant, Joe (Cognite LLC)",
#     "job_title": "3rd Party Service Provider"
# }
# ...

# %% [markdown]
# ## Create the Cognite Client

# %%
# Logic moved to utils/cognite_groups_export.py

# %% [markdown]
# # Check Identity

# %%
# Logic moved to utils/cognite_groups_export.py
# Out:
# User Identifier: kx-ut87k69sRB2pqrRzqZg
# Name: Joe O'Bryant
# Email: Joe_O'Bryant@oxy.com
# Full profile: {
#     "user_identifier": "kx-ut87k69sRB2pqrRzqZg",
#     "last_updated_time": "2025-11-06 20:46:41.667+00:00",
#     "given_name": "Joe",
#     "surname": "O'Bryant",
#     "email": "Joe_O'Bryant@oxy.com",
#     "display_name": "O'Bryant, Joe (Cognite LLC)"
# }
# C:\Users\JoeO'Bryant\.cognite\token_cache\oxy-aws-dev.json

# %% [markdown]
# ## Check Login Status By Running Assets List

# %%
# Logic moved to utils/cognite_groups_export.py
# Out:
# Fetching groups for customer: oxy-oog-dev
#   ✓ Found 8 groups for oxy-oog-dev
# Fetching groups for customer: oxy-aws
#   ✓ Found 37 groups for oxy-aws
# Fetching groups for customer: oxy-aws-dev
#   ✓ Found 39 groups for oxy-aws-dev
#
# Total customers processed: 3

# %%
# Logic moved to utils/cognite_groups_export.py
# Out:
# ...
# RAW CAPABILITIES FROM GROUPS
# ...
#
# ...
# Customer: oxy-oog-dev (8 groups)
# ...
#
# --- Group 1: temp-cdf-extractor-oog-dev ---
# Group ID: 2259313790107193
# Source ID: 02f1c53d-59b5-48be-8b61-5c21ab1db42e
#
# Capabilities (7 total):
#
#   Capability 1:
#     Type: TimeSeriesAcl
#     Raw object: TimeSeriesAcl(actions=[<TimeSeriesAcl Action.Read: 'READ'>, <TimeSeriesAcl Action.Write: 'WRITE'>], scope=AllScope())
# ...

# %%
# Logic moved to utils/cognite_groups_export.py

# %%
# Logic moved to utils/cognite_groups_export.py

# %%
# Logic moved to utils/cognite_groups_export.py

# %%
# Logic moved to utils/cognite_groups_export.py
# Out:
# ✓ Saved 8 groups for oxy-oog-dev to sheet 'oxy-oog-dev'
# ✓ Saved 37 groups for oxy-aws to sheet 'oxy-aws'
# ✓ Saved 39 groups for oxy-aws-dev to sheet 'oxy-aws-dev'
#
# ✅ Excel file saved: c:\Users\JoeO'Bryant\OneDrive - Cognite AS\projects\cognite_python_sdk_training\using-cognite-python-sdk\notebooks\groups_by_customer.xlsx
